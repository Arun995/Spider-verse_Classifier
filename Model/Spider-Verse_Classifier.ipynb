# %% [markdown]
# <h1 style='color:red' align='center' bold>Spider-Verse Classifier<h1>

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:blue'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/tom_1.jpg')
img.shape
# Out:
# (281, 500, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (281, 500)

# %%
gray
# Out:
# array([[ 25,  25,  25, ...,  83,  83,  83],
#        [ 25,  25,  25, ...,  84,  84,  84],
#        [ 25,  25,  25, ...,  84,  84,  84],
#        ...,
#        [ 47,  47,  47, ..., 110, 110, 110],
#        [ 47,  47,  47, ..., 110, 110, 110],
#        [ 47,  47,  47, ..., 110, 110, 110]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[250,  49, 139, 139]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (250, 49, 139, 139)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:blue'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (139, 139, 3)

# %% [markdown]
# <h3 style='color:blue'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### We can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:blue'>(4) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/tom_1.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/tom_1.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
original_image = cv2.imread('./test_images/tom_2.jpg')
plt.imshow(original_image)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/tom_2.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Andrew Garfield',
#  './dataset/Tobey Maguire',
#  './dataset/Tom Holland']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        try:
            print(f"Processing image: {entry.path}")
            roi_color = get_cropped_image_if_2_eyes(entry.path)
            if roi_color is not None:
                cropped_folder = path_to_cr_data + celebrity_name
                if not os.path.exists(cropped_folder):
                    os.makedirs(cropped_folder)
                    cropped_image_dirs.append(cropped_folder)
                    print("Generating cropped images in folder: ", cropped_folder)
                
                cropped_file_name = celebrity_name + str(count) + ".png"
                cropped_file_path = os.path.join(cropped_folder, cropped_file_name)
                cv2.imwrite(cropped_file_path, roi_color)
                celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
                count += 1
            else:
                print(f"No face detected in image: {entry.path}")
        except Exception as e:
            print(f"Error processing image: {entry.path}")
            print(f"Error message: {e}")
# Out:
# Processing image: ./dataset/Andrew Garfield\image_1.jpg
# Generating cropped images in folder:  ./dataset/cropped/Andrew Garfield
# Processing image: ./dataset/Andrew Garfield\image_10.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_10.jpg
# Processing image: ./dataset/Andrew Garfield\image_100.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_100.jpg
# Processing image: ./dataset/Andrew Garfield\image_11.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_11.jpg
# Processing image: ./dataset/Andrew Garfield\image_12.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_12.jpg
# Processing image: ./dataset/Andrew Garfield\image_13.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_13.jpg
# Processing image: ./dataset/Andrew Garfield\image_14.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_14.jpg
# Processing image: ./dataset/Andrew Garfield\image_15.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_15.jpg
# Processing image: ./dataset/Andrew Garfield\image_16.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_16.jpg
# Processing image: ./dataset/Andrew Garfield\image_17.jpg
# Processing image: ./dataset/Andrew Garfield\image_18.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_18.jpg
# Processing image: ./dataset/Andrew Garfield\image_19.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_19.jpg
# Processing image: ./dataset/Andrew Garfield\image_2.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_2.jpg
# Processing image: ./dataset/Andrew Garfield\image_20.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_20.jpg
# Processing image: ./dataset/Andrew Garfield\image_21.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_21.jpg
# Processing image: ./dataset/Andrew Garfield\image_22.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_22.jpg
# Processing image: ./dataset/Andrew Garfield\image_23.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_23.jpg
# Processing image: ./dataset/Andrew Garfield\image_24.jpg
# Processing image: ./dataset/Andrew Garfield\image_25.jpg
# Processing image: ./dataset/Andrew Garfield\image_26.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_26.jpg
# Processing image: ./dataset/Andrew Garfield\image_27.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_27.jpg
# Processing image: ./dataset/Andrew Garfield\image_28.jpg
# Processing image: ./dataset/Andrew Garfield\image_29.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_29.jpg
# Processing image: ./dataset/Andrew Garfield\image_3.jpg
# Processing image: ./dataset/Andrew Garfield\image_30.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_30.jpg
# Processing image: ./dataset/Andrew Garfield\image_31.jpg
# Processing image: ./dataset/Andrew Garfield\image_32.jpg
# Processing image: ./dataset/Andrew Garfield\image_33.jpg
# Processing image: ./dataset/Andrew Garfield\image_34.jpg
# Processing image: ./dataset/Andrew Garfield\image_35.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_35.jpg
# Processing image: ./dataset/Andrew Garfield\image_36.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_36.jpg
# Processing image: ./dataset/Andrew Garfield\image_37.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_37.jpg
# Processing image: ./dataset/Andrew Garfield\image_38.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_38.jpg
# Processing image: ./dataset/Andrew Garfield\image_39.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_39.jpg
# Processing image: ./dataset/Andrew Garfield\image_4.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_4.jpg
# Processing image: ./dataset/Andrew Garfield\image_40.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_40.jpg
# Processing image: ./dataset/Andrew Garfield\image_41.jpg
# Processing image: ./dataset/Andrew Garfield\image_42.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_42.jpg
# Processing image: ./dataset/Andrew Garfield\image_43.jpg
# Processing image: ./dataset/Andrew Garfield\image_44.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_44.jpg
# Processing image: ./dataset/Andrew Garfield\image_45.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_45.jpg
# Processing image: ./dataset/Andrew Garfield\image_46.jpg
# No face detected in image: ./dataset/Andrew Garfield\image_46.jpg
# Processing image: ./dataset/Andrew Garfield\image_47.jpg
# No face detected in image: ./dataset/Andrew Garfield\image
jpg
# No face detected in image: ./dataset/Tobey Maguire\image_81.jpg
# Processing image: ./dataset/Tobey Maguire\image_82.jpg
# Processing image: ./dataset/Tobey Maguire\image_83.jpg
# Processing image: ./dataset/Tobey Maguire\image_84.jpg
# Processing image: ./dataset/Tobey Maguire\image_85.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_85.jpg
# Processing image: ./dataset/Tobey Maguire\image_86.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_86.jpg
# Processing image: ./dataset/Tobey Maguire\image_87.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_87.jpg
# Processing image: ./dataset/Tobey Maguire\image_88.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_88.jpg
# Processing image: ./dataset/Tobey Maguire\image_89.jpg
# Processing image: ./dataset/Tobey Maguire\image_9.jpg
# Processing image: ./dataset/Tobey Maguire\image_90.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_90.jpg
# Processing image: ./dataset/Tobey Maguire\image_91.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_91.jpg
# Processing image: ./dataset/Tobey Maguire\image_92.jpg
# Processing image: ./dataset/Tobey Maguire\image_93.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_93.jpg
# Processing image: ./dataset/Tobey Maguire\image_94.jpg
# Processing image: ./dataset/Tobey Maguire\image_95.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_95.jpg
# Processing image: ./dataset/Tobey Maguire\image_96.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_96.jpg
# Processing image: ./dataset/Tobey Maguire\image_97.jpg
# Processing image: ./dataset/Tobey Maguire\image_98.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_98.jpg
# Processing image: ./dataset/Tobey Maguire\image_99.jpg
# No face detected in image: ./dataset/Tobey Maguire\image_99.jpg
# Processing image: ./dataset/Tom Holland\image_1.jpg
# No face detected in image: ./dataset/Tom Holland\image_1.jpg
# Processing image: ./dataset/Tom Holland\image_10.jpg
# No face detected in image: ./dataset/Tom Holland\image_10.jpg
# Processing image: ./dataset/Tom Holland\image_100.jpg
# No face detected in image: ./dataset/Tom Holland\image_100.jpg
# Processing image: ./dataset/Tom Holland\image_11.jpg
# Generating cropped images in folder:  ./dataset/cropped/Tom Holland
# Processing image: ./dataset/Tom Holland\image_12.jpg
# Processing image: ./dataset/Tom Holland\image_13.jpg
# No face detected in image: ./dataset/Tom Holland\image_13.jpg
# Processing image: ./dataset/Tom Holland\image_14.jpg
# Processing image: ./dataset/Tom Holland\image_15.jpg
# Processing image: ./dataset/Tom Holland\image_16.jpg
# Processing image: ./dataset/Tom Holland\image_17.jpg
# No face detected in image: ./dataset/Tom Holland\image_17.jpg
# Processing image: ./dataset/Tom Holland\image_18.jpg
# Processing image: ./dataset/Tom Holland\image_19.jpg
# No face detected in image: ./dataset/Tom Holland\image_19.jpg
# Processing image: ./dataset/Tom Holland\image_2.jpg
# No face detected in image: ./dataset/Tom Holland\image_2.jpg
# Processing image: ./dataset/Tom Holland\image_20.jpg
# Processing image: ./dataset/Tom Holland\image_21.jpg
# No face detected in image: ./dataset/Tom Holland\image_21.jpg
# Processing image: ./dataset/Tom Holland\image_22.jpg
# Processing image: ./dataset/Tom Holland\image_23.jpg
# Processing image: ./dataset/Tom Holland\image_24.jpg
# Processing image: ./dataset/Tom Holland\image_25.jpg
# Processing image: ./dataset/Tom Holland\image_26.jpg
# No face detected in image: ./dataset/Tom Holland\image_26.jpg
# Processing image: ./dataset/Tom Holland\image_27.jpg
# No face detected in image: ./dataset/Tom Holland\image_27.jpg
# Processing image: ./dataset/Tom Holland\image_28.jpg
# Processing image: ./dataset/Tom Holland\image_29.jpg
# Processing image: ./dataset/Tom Holland\image_3.jpg
# No face detected in image: ./dataset/Tom Holland\image_3.jpg
# Processing image: ./dataset/Tom Holland\image_30.jpg
# No face detected in image: ./dataset/Tom Holland\image_30.jpg
# Processing image: ./dataset/Tom Holland\image_31.jpg
# No face detected in image: ./dataset/Tom Holland\image_31.jpg
# Processing image: ./dataset/Tom Holland\image_32.jpg
# Processing image: ./dataset/Tom Holland\image_33.jpg
# No face detected in image: ./dataset/Tom Holland\image_33.jpg
# Processing image: ./dataset/Tom Holland\image_34.jpg
# Processing image: ./dataset/Tom Holland\image_35.jpg
# No face detected in image: ./dataset/Tom Holland\image_35.jpg
# Processing image: ./dataset/Tom Holland\image_36.jpg
# Processing image: ./dataset/Tom Holland\image_37.jpg
# No face detected in image: ./dataset/Tom Holland\image_37.jpg
# Processing image: ./dataset/Tom Holland\image_38.jpg
# Processing image: ./dataset/Tom Holland\image_39.jpg
# No face detected in image: ./dataset/Tom Holland\image_39.jpg
# Processing image: ./dataset/Tom Holland\image_4.jpg
# No face detected in image: ./dataset/Tom Holland\image_4.jpg
# Processing image: ./dataset/Tom Holland\image_40.jpg
# No face detected in image: ./dataset/Tom Holland\image_40.jpg
# Processing image: ./dataset/Tom Holland\image_41.jpg
# Processing image: ./dataset/Tom Holland\image_42.jpg
# No face detected in image: ./dataset/Tom Holland\image_42.jpg
# Processing image: ./dataset/Tom Holland\image_43.jpg
# Processing image: ./dataset/Tom Holland\image_44.jpg
# No face detected in image: ./dataset/Tom Holland\image_44.jpg
# Processing image: ./dataset/Tom Holland\image_45.jpg
# Processing image: ./dataset/Tom Holland\image_46.jpg
# Processing image: ./dataset/Tom Holland\image_47.jpg
# Processing image: ./dataset/Tom Holland\image_48.jpg
# No face detected in image: ./dataset/Tom Holland\image_48.jpg
# Processing image: ./dataset/Tom Holland\image_49.jpg
# No face detected in image: ./dataset/Tom Holland\image_49.jpg
# Processing image: ./dataset/Tom Holland\image_5.jpg
# No face detected in image: ./dataset/Tom Holland\image_5.jpg
# Processing image: ./dataset/Tom Holland\image_50.jpg
# Processing image: ./dataset/Tom Holland\image_51.jpg
# No face detected in image: ./dataset/Tom Holland\image_51.jpg
# Processing image: ./dataset/Tom Holland\image_52.jpg
# No face detected in image: ./dataset/Tom Holland\image_52.jpg
# Processing image: ./dataset/Tom Holland\image_53.jpg
# Processing image: ./dataset/Tom Holland\image_54.jpg
# No face detected in image: ./dataset/Tom Holland\image_54.jpg
# Processing image: ./dataset/Tom Holland\image_55.jpg
# No face detected in image: ./dataset/Tom Holland\image_55.jpg
# Processing image: ./dataset/Tom Holland\image_56.jpg
# No face detected in image: ./dataset/Tom Holland\image_56.jpg
# Processing image: ./dataset/Tom Holland\image_57.jpg
# No face detected in image: ./dataset/Tom Holland\image_57.jpg
# Processing image: ./dataset/Tom Holland\image_58.jpg
# No face detected in image: ./dataset/Tom Holland\image_58.jpg
# Processing image: ./dataset/Tom Holland\image_59.jpg
# No face detected in image: ./dataset/Tom Holland\image_59.jpg
# Processing image: ./dataset/Tom Holland\image_6.jpg
# No face detected in image: ./dataset/Tom Holland\image_6.jpg
# Processing image: ./dataset/Tom Holland\image_60.jpg
# No face detected in image: ./dataset/Tom Holland\image_60.jpg
# Processing image: ./dataset/Tom Holland\image_61.jpg
# Processing image: ./dataset/Tom Holland\image_62.jpg
# No face detected in image: ./dataset/Tom Holland\image_62.jpg
# Processing image: ./dataset/Tom Holland\image_63.jpg
# Processing image: ./dataset/Tom Holland\image_64.jpg
# Processing image: ./dataset/Tom Holland\image_65.jpg
# No face detected in image: ./dataset/Tom Holland\image_65.jpg
# Processing image: ./dataset/Tom Holland\image_66.jpg
# Processing image: ./dataset/Tom Holland\image_67.jpg
# No face detected in image: ./dataset/Tom Holland\image_67.jpg
# Processing image: ./dataset/Tom Holland\image_68.jpg
# Processing image: ./dataset/Tom Holland\image_69.jpg
# No face detected in image: ./dataset/Tom Holland\image_69.jpg
# Processing image: ./dataset/Tom Holland\image_7.jpg
# Processing image: ./dataset/Tom Holland\image_70.jpg
# Processing image: ./dataset/Tom Holland\image_71.jpg
# Processing image: ./dataset/Tom Holland\image_72.jpg
# No face detected in image: ./dataset/Tom Holland\image_72.jpg
# Processing image: ./dataset/Tom Holland\image_73.jpg
# No face detected in image: ./dataset/Tom Holland\image_73.jpg
# Processing image: ./dataset/Tom Holland\image_74.jpg
# No face detected in image: ./dataset/Tom Holland\image_74.jpg
# Processing image: ./dataset/Tom Holland\image_75.jpg
# No face detected in image: ./dataset/Tom Holland\image_75.jpg
# Processing image: ./dataset/Tom Holland\image_76.jpg
# Processing image: ./dataset/Tom Holland\image_77.jpg
# No face detected in image: ./dataset/Tom Holland\image_77.jpg
# Processing image: ./dataset/Tom Holland\image_78.jpg
# No face detected in image: ./dataset/Tom Holland\image_78.jpg
# Processing image: ./dataset/Tom Holland\image_79.jpg
# No face detected in image: ./dataset/Tom Holland\image_79.jpg
# Processing image: ./dataset/Tom Holland\image_8.jpg
# Processing image: ./dataset/Tom Holland\image_80.jpg
# No face detected in image: ./dataset/Tom Holland\image_80.jpg
# Processing image: ./dataset/Tom Holland\image_81.jpg
# No face detected in image: ./dataset/Tom Holland\image_81.jpg
# Processing image: ./dataset/Tom Holland\image_82.jpg
# No face detected in image: ./dataset/Tom Holland\image_82.jpg
# Processing image: ./dataset/Tom Holland\image_83.jpg
# No face detected in image: ./dataset/Tom Holland\image_83.jpg
# Processing image: ./dataset/Tom Holland\image_84.jpg
# No face detected in image: ./dataset/Tom Holland\image_84.jpg
# Processing image: ./dataset/Tom Holland\image_85.jpg
# No face detected in image: ./dataset/Tom Holland\image_85.jpg
# Processing image: ./dataset/Tom Holland\image_86.jpg
# No face detected in image: ./dataset/Tom Holland\image_86.jpg
# Processing image: ./dataset/Tom Holland\image_87.jpg
# Processing image: ./dataset/Tom Holland\image_88.jpg
# No face detected in image: ./dataset/Tom Holland\image_88.jpg
# Processing image: ./dataset/Tom Holland\image_89.jpg
# No face detected in image: ./dataset/Tom Holland\image_89.jpg
# Processing image: ./dataset/Tom Holland\image_9.jpg
# Processing image: ./dataset/Tom Holland\image_90.jpg
# Processing image: ./dataset/Tom Holland\image_91.jpg
# No face detected in image: ./dataset/Tom Holland\image_91.jpg
# Processing image: ./dataset/Tom Holland\image_92.jpg
# Processing image: ./dataset/Tom Holland\image_93.jpg
# Processing image: ./dataset/Tom Holland\image_94.jpg
# No face detected in image: ./dataset/Tom Holland\image_94.jpg
# Processing image: ./dataset/Tom Holland\image_95.jpg
# No face detected in image: ./dataset/Tom Holland\image_95.jpg
# Processing image: ./dataset/Tom Holland\image_96.jpg
# Processing image: ./dataset/Tom Holland\image_97.jpg
# No face detected in image: ./dataset/Tom Holland\image_97.jpg
# Processing image: ./dataset/Tom Holland\image_98.jpg
# No face detected in image: ./dataset/Tom Holland\image_98.jpg
# Processing image: ./dataset/Tom Holland\image_99.jpg

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Andrew Garfield': ['./dataset/cropped/Andrew Garfield\\Andrew Garfield1.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield10.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield11.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield12.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield13.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield14.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield15.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield16.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield17.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield18.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield19.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield2.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield20.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield21.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield22.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield23.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield24.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield25.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield26.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield27.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield28.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield29.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield3.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield30.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield4.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield5.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield6.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield7.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield8.png',
#   './dataset/cropped/Andrew Garfield\\Andrew Garfield9.png'],
#  'Tobey Maguire': ['./dataset/cropped/Tobey Maguire\\Tobey Maguire1.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire10.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire11.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire12.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire13.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire14.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire15.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire16.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire17.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire18.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire19.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire2.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire20.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire21.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire22.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire23.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire24.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire25.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire26.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire27.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire28.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire29.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire3.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire30.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire31.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire32.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire33.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire34.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire35.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire36.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire37.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire38.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire39.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire4.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire40.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire41.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire42.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire43.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire44.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire45.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire46.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire47.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire48.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire5.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire6.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire7.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire8.png',
#   './dataset/cropped/Tobey Maguire\\Tobey Maguire9.png'],
#  'Tom Holland': ['./dataset/cropped/Tom Holland\\Tom Holland1.png',
#   './dataset/cropped/Tom Holland\\Tom Holland10.png',
#   './dataset/cropped/Tom Holland\\Tom Holland11.png',
#   './dataset/cropped/Tom Holland\\Tom Holland12.png',
#   './dataset/cropped/Tom Holland\\Tom Holland13.png',
#   './dataset/cropped/Tom Holland\\Tom Holland14.png',
#   './dataset/cropped/Tom Holland\\Tom Holland15.png',
#   './dataset/cropped/Tom Holland\\Tom Holland16.png',
#   './dataset/cropped/Tom Holland\\Tom Holland17.png',
#   './dataset/cropped/Tom Holland\\Tom Holland18.png',
#   './dataset/cropped/Tom Holland\\Tom Holland19.png',
#   './dataset/cropped/Tom Holland\\Tom Holland2.png',
#   './dataset/cropped/Tom Holland\\Tom Holland20.png',
#   './dataset/cropped/Tom Holland\\Tom Holland21.png',
#   './dataset/cropped/Tom Holland\\Tom Holland22.png',
#   './dataset/cropped/Tom Holland\\Tom Holland23.png',
#   './dataset/cropped/Tom Holland\\Tom Holland24.png',
#   './dataset/cropped/Tom Holland\\Tom Holland25.png',
#   './dataset/cropped/Tom Holland\\Tom Holland26.png',
#   './dataset/cropped/Tom Holland\\Tom Holland27.png',
#   './dataset/cropped/Tom Holland\\Tom Holland28.png',
#   './dataset/cropped/Tom Holland\\Tom Holland29.png',
#   './dataset/cropped/Tom Holland\\Tom Holland3.png',
#   './dataset/cropped/Tom Holland\\Tom Holland30.png',
#   './dataset/cropped/Tom Holland\\Tom Holland31.png',
#   './dataset/cropped/Tom Holland\\Tom Holland32.png',
#   './dataset/cropped/Tom Holland\\Tom Holland33.png',
#   './dataset/cropped/Tom Holland\\Tom Holland34.png',
#   './dataset/cropped/Tom Holland\\Tom Holland35.png',
#   './dataset/cropped/Tom Holland\\Tom Holland36.png',
#   './dataset/cropped/Tom Holland\\Tom Holland37.png',
#   './dataset/cropped/Tom Holland\\Tom Holland38.png',
#   './dataset/cropped/Tom Holland\\Tom Holland39.png',
#   './dataset/cropped/Tom Holland\\Tom Holland4.png',
#   './dataset/cropped/Tom Holland\\Tom Holland40.png',
#   './dataset/cropped/Tom Holland\\Tom Holland41.png',
#   './dataset/cropped/Tom Holland\\Tom Holland5.png',
#   './dataset/cropped/Tom Holland\\Tom Holland6.png',
#   './dataset/cropped/Tom Holland\\Tom Holland7.png',
#   './dataset/cropped/Tom Holland\\Tom Holland8.png',
#   './dataset/cropped/Tom Holland\\Tom Holland9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Andrew Garfield': 0, 'Tobey Maguire': 1, 'Tom Holland': 2}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        
        # Check if the image is loaded correctly
        if img is None:
            print(f"Error loading image: {training_image}")
            continue  # Skip this image and continue with the next one

        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img, 'db1', 5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32 * 32 * 3, 1), scalled_img_har.reshape(32 * 32, 1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[226],
#        [235],
#        [245],
#        ...,
#        [ 36],
#        [ 38],
#        [ 16]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (102, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)

# %%
print(classification_report(y_test, pipe.predict(X_test)))

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)

# %%
best_estimators['random_forest'].score(X_test,y_test)

# %%
best_estimators['logistic_regression'].score(X_test,y_test)

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')

# %%
class_dict
# Out:
# {'Andrew Garfield': 0, 'Tobey Maguire': 1, 'Tom Holland': 2}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\aruna\anaconda3\lib\site-packages (1.4.2)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
